# %%
import pandas as p

# %%
data = p.read_csv('/Users/vishalnigam/Downloads/IRIS.csv')

# %% [markdown]
# # Showcasing the data

# %%
data.head()
# Out:
#     f1        f2   f3        f4   f5        f6   f7        f8  Target
# 0  5.1  0.222222  3.5  0.625000  1.4  0.067797  0.2  0.041667  setosa
# 1  4.9  0.166667  3.0  0.416667  1.4  0.067797  0.2  0.041667  setosa
# 2  4.7  0.111111  3.2  0.500000  1.3  0.050847  0.2  0.041667  setosa
# 3  4.6  0.083333  3.1  0.458333  1.5  0.084746  0.2  0.041667  setosa
# 4  5.0  0.194444  3.6  0.666667  1.4  0.067797  0.2  0.041667  setosa

# %%
data
# Out:
#      f1        f2   f3        f4   f5        f6   f7        f8     Target
# 0   5.1  0.222222  3.5  0.625000  1.4  0.067797  0.2  0.041667     setosa
# 1   4.9  0.166667  3.0  0.416667  1.4  0.067797  0.2  0.041667     setosa
# 2   4.7  0.111111  3.2  0.500000  1.3  0.050847  0.2  0.041667     setosa
# 3   4.6  0.083333  3.1  0.458333  1.5  0.084746  0.2  0.041667     setosa
# 4   5.0  0.194444  3.6  0.666667  1.4  0.067797  0.2  0.041667     setosa
# 5   5.4  0.305556  3.9  0.791667  1.7  0.118644  0.4  0.125000     setosa
# 6   4.6  0.083333  3.4  0.583333  1.4  0.067797  0.3  0.083333     setosa
# 7   5.0  0.194444  3.4  0.583333  1.5  0.084746  0.2  0.041667     setosa
# 8   4.4  0.027778  2.9  0.375000  1.4  0.067797  0.2  0.041667     setosa
# 9   4.9  0.166667  3.1  0.458333  1.5  0.084746  0.1  0.010000     setosa
# 10  5.4  0.305556  3.7  0.708333  1.5  0.084746  0.2  0.041667     setosa
# 11  4.8  0.138889  3.4  0.583333  1.6  0.101695  0.2  0.041667     setosa
# ...

# %%
labels= data['Target']

# %%
features = data[['f1','f2','f3','f4']]

# %%
features
# Out:
#      f1        f2   f3        f4
# 0   5.1  0.222222  3.5  0.625000
# 1   4.9  0.166667  3.0  0.416667
# 2   4.7  0.111111  3.2  0.500000
# 3   4.6  0.083333  3.1  0.458333
# 4   5.0  0.194444  3.6  0.666667
# 5   5.4  0.305556  3.9  0.791667
# 6   4.6  0.083333  3.4  0.583333
# 7   5.0  0.194444  3.4  0.583333
# 8   4.4  0.027778  2.9  0.375000
# 9   4.9  0.166667  3.1  0.458333
# 10  5.4  0.305556  3.7  0.708333
# 11  4.8  0.138889  3.4  0.583333
# 12  4.8  0.138889  3.0  0.416667
# 13  4.3  0.010000  3.0  0.416667
# 14  5.8  0.416667  4.0  0.833333
# 15  5.7  0.388889  4.4  0.999900
# 16  5.4  0.305556  3.9  0.791667
# 17  5.1  0.222222  3.5  0.625000
# 18  5.7  0.388889  3.8  0.750000
# 19  5.1  0.222222  3.8  0.750000
# 20  5.4  0.305556  3.4  0.583333
# 21  5.1  0.222222  3.7  0.708333
# 22  4.6  0.083333  3.6  0.666667
# 23  5.1  0.222222  3.3  0.541667
# 24  4.8  0.138889  3.4  0.583333
# 25  5.0  0.194444  3.0  0.416667
# 26  5.0  0.194444  3.4  0.583333
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train,test,train_labels,test_labels = train_test_split(features,labels,test_size = 0.33)

# %%
train
# Out:
#      f1        f2   f3        f4
# 69  6.3  0.555556  2.9  0.375000
# 4   5.0  0.194444  3.6  0.666667
# 47  6.7  0.666667  3.1  0.458333
# 35  5.5  0.333333  2.3  0.125000
# 27  5.2  0.250000  3.5  0.625000
# 18  5.7  0.388889  3.8  0.750000
# 96  7.4  0.861111  2.8  0.333333
# 0   5.1  0.222222  3.5  0.625000
# 23  5.1  0.222222  3.3  0.541667
# 31  5.4  0.305556  3.4  0.583333
# 61  5.7  0.388889  2.6  0.250000
# 15  5.7  0.388889  4.4  0.999900
# 58  6.8  0.694444  2.8  0.333333
# 88  7.7  0.944444  2.8  0.333333
# 22  4.6  0.083333  3.6  0.666667
# 72  4.9  0.166667  2.5  0.208333
# 37  5.7  0.388889  2.8  0.333333
# 48  5.6  0.361111  3.0  0.416667
# 51  5.6  0.361111  2.5  0.208333
# 82  6.5  0.611111  3.0  0.416667
# 85  6.0  0.472222  2.2  0.083333
# 56  6.4  0.583333  2.9  0.375000
# 73  7.3  0.833333  2.9  0.375000
# 79  5.7  0.388889  2.5  0.208333
# 89  6.3  0.555556  2.7  0.291667
# 55  6.1  0.500000  2.8  0.333333
# 28  5.2  0.250000  3.4  0.583333
# ...

# %%
from  sklearn.linear_model import LogisticRegression

# %%
logic =  LogisticRegression()

# %%
model = logic.fit(train,train_labels)

# %%
preds= logic.predict(test)
print(preds)
# Out:
# ['virginica' 'setosa' 'versicolor' 'versicolor' 'versicolor' 'versicolor'
#  'virginica' 'versicolor' 'virginica' 'setosa' 'versicolor' 'virginica'
#  'versicolor' 'setosa' 'virginica' 'setosa' 'virginica' 'virginica'
#  'setosa' 'setosa' 'virginica' 'virginica' 'virginica' 'virginica'
#  'virginica' 'setosa' 'versicolor' 'virginica' 'setosa' 'setosa' 'setosa'
#  'virginica' 'versicolor']

# %%
test.head()
# Out:
#      f1        f2   f3        f4
# 70  6.5  0.611111  3.0  0.416667
# 17  5.1  0.222222  3.5  0.625000
# 49  5.8  0.416667  2.7  0.291667
# 65  6.0  0.472222  2.7  0.291667
# 39  4.9  0.166667  2.4  0.166667

# %%
test_record  = test.loc[[8]]

# %%
test_record
# Out:
#     f1        f2   f3     f4
# 8  4.4  0.027778  2.9  0.375

# %%
model.predict(test_record)
# Out:
# array(['setosa'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(test_labels,preds))
# Out:
# 0.818181818182
